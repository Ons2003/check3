# %%
#QUESTION 1
list=[2,3,6]
prod = 1  
for i in list : 
  prod = prod * i
print(prod)

# %%
#QUESTION 2
def takeSecond(elem):
    return elem[1]
list_1 = [(2, 5), (1, 2), (4, 4), (2, 3), (2, 1) ] 
for i in list_1 :
  list_1.sort(key=takeSecond)
print(list_1)

# %%
#QUESTION 3
d1 = {'a': 100, 'b': 200, 'c':300}
d2 = {'a': 300, 'b': 200, 'd':400}
d3 = {}
d3=d2
d3.update(d1)
for i in d3 :
    if (i in d2) and (i in d1) :
      d3[i] = d2[i]+d1[i]'''
print(d3)
# Out:
# {'a': 300, 'b': 200, 'd': 400}

# %%
#QUESTION 4
n = input("enter a number")
n = int(n)
d = {}
for i in range(1,n+1) :
  d[str(i)] = i*i
print(d)

# %%
#QUESTION 5
list= [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
list.sort(key = takeSecond, reverse=True)
print(list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bb99ac460c19> in <module>()
#       1 #QUESTION 5
#       2 list= [('item1', '12.20'), ('item2', '15.10'), ('item3', '24.5')]
# ----> 3 list.sort(key = takeSecond, reverse=True)
#       4 print(list)
#
# NameError: name 'takeSecond' is not defined
